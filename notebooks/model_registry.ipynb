# %% [markdown]
# ## Instalando o MLflow

# %%
# %%capture
# !pip install mlflow -q

# %% [markdown]
# ## import das bibliotecas

# %%
import os
import mlflow
import numpy as np

# %% [markdown]
# ## Configurando o MLflow

# %%
MLFLOW_TRACKING_URI = 'https://dagshub.com/redsonlopez/puc_mlops.mlflow'
MLFLOW_TRACKING_USERNAME = 'redsonlopez'
MLFLOW_TRACKING_PASSWORD = 'e5d3980c463b148f5230380ed4ed8ce3f677db91'
os.environ['MLFLOW_TRACKING_USERNAME'] = MLFLOW_TRACKING_USERNAME
os.environ['MLFLOW_TRACKING_PASSWORD'] = MLFLOW_TRACKING_PASSWORD

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# %% [markdown]
# ## Criando um client para comunicar com o registro no DagsHub

# %%
client = mlflow.MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
client

# %% [markdown]
# ## Recebendo o modelo registrado e suas versões

# %%
registered_model = client.get_registered_model('fetal_health')

# %%
registered_model.latest_versions
# Out:
# []

# %% [markdown]
# ## Obtendo o id da execução do modelo

# %%
#run_id = registered_model.latest_versions[-1].run_id

# Jeito manual de executar usando o retorno do train.py
run_id = '389aaaea008f4a6891f333a1bce45c7c'

# %% [markdown]
# ## Carregando o modelo

# %%
logged_model = f'runs:/{run_id}/model'
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 logged_model = f'runs:/{run_id}/model'
#       2 #loaded_model = mlflow.pyfunc.load_model(logged_model)
# ----> 3 loaded_model = mlflow.sklearn.load_model(logged_model)
#
# File ~/.cache/pypoetry/virtualenvs/puc-mlops-jGkwIRr8-py3.12/lib/python3.12/site-packages/mlflow/sklearn/__init__.py:652, in load_model(model_uri, dst_path)
#     617 def load_model(model_uri, dst_path=None):
#     618     """
#     619     Load a scikit-learn model from a local file or a run.
#     620
#    (...)    650         predictions = sk_model.predict(pandas_df)
#     651     """
# --> 652     local_model_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     653     flavor_conf = _get_flavor_configuration(model_path=local_model_path, flavor_name=FLAVOR_NAME)
#     654     _add_code_from_conf_to_system_path(local_model_path, flavor_conf)
#
# File ~/.cache/pypoetry/virtualenvs/puc-mlops-jGkwIRr8-py3.12/lib/python3.12/site-packages/mlflow/tracking/artifact_utils.py:117, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info)
#     111     if isinstance(repo, ModelsArtifactRepository):
#     112         return repo.download_artifacts(
#     113             artifact_path=artifact_path,
#     114             dst_path=output_path,
#     115             lineage_header_info=lineage_header_info,
#     116         )
# --> 117     return repo.download_artifacts(artifact_path=artifact_path, dst_path=output_path)
#     118 except Exception as e:
#     119     if artifact_uri.startswith("m-"):
#     120         # When a Model ID like string is passed, suggest using 'models:/{artifact_uri}' instead.
#
# File ~/.cache/pypoetry/virtualenvs/puc-mlops-jGkwIRr8-py3.12/lib/python3.12/site-packages/mlflow/store/artifact/runs_artifact_repo.py:200, in RunsArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     197 run_out_path: Optional[str] = None
#     198 try:
#     199     # This fails when the run has no artifacts, so we catch the exception
# --> 200     run_out_path = self.repo.download_artifacts(artifact_path, dst_path)
#     201 except Exception:
#     202     _logger.debug(
#     203         f"Failed to download artifacts from {self.artifact_uri}/{artifact_path}.",
#     204         exc_info=True,
#     205     )
#
# File ~/.cache/pypoetry/virtualenvs/puc-mlops-jGkwIRr8-py3.12/lib/python3.12/site-packages/mlflow/store/artifact/artifact_repo.py:298, in ArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     296 tracebacks = {}
#     297 with ArtifactProgressBar.files(desc="Downloading artifacts", total=len(futures)) as pbar:
# --> 298     for f in as_completed(futures):
#     299         try:
#     300             f.result()
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:243, in as_completed(fs, timeout)
#     238     if wait_timeout < 0:
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#     246     finished = waiter.finished_futures
#
# File /usr/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /usr/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Fazendo uma predição com o modelo carregado

# %%
accelerations = 0
fetal_movement = 0
uterine_contractions = 0
severe_decelerations = 0

# %%
received_data = np.array([
        accelerations,
        fetal_movement,
        uterine_contractions,
        severe_decelerations,
    ]).reshape(1, -1)

# %%
received_data

# %%
loaded_model.predict(received_data)
